# %%
import sys
sys.path.append("..")

# %%
from config import weather_api_key

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# # Import the requests library.
import requests
# # Import the API key.
# api_key = ""

# %%
# from config import weather_api_key

# %%
# # Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"

# # Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# # print(url)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
#                           "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | matane
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | broome
# Processing Record 6 of Set 1 | batticaloa
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | guerrero negro
# Processing Record 9 of Set 1 | kuryk
# Processing Record 10 of Set 1 | bend
# Processing Record 11 of Set 1 | tura
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | nanakuli
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | niigata
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | north bend
# Processing Record 22 of Set 1 | camaqua
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | souillac
# Processing Record 27 of Set 1 | hirara
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | cockburn town
# Processing Record 30 of Set 1 | bintulu
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | tautira
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | najran
# Processing Record 39 of Set 1 | torit
# Processing Record 40 of Set 1 | makakilo city
# Processing Record 41 of Set 1 | matay
# Processing Record 42 of Set 1 | amuntai
# Processing Record 43 of Set 1 | barras
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | kashmor
# Processing Record 48 of Set 1 | hailar
# Processing Record 49 of Set 1 | pevek
# Processing Record 50 of Set 1 | hobyo
# Processing Record 1 of Set 2 | aklavik
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | vila velha
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | geraldton
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | anadyr
# Processing Record 13 of Set 2 | constitucion
# Processing Record 14 of Set 2 | bentiu
# Processing Record 15 of Set 2 | zgorzelec
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | atasu
# Processing Record 18 of Set 2 | kasane
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | faya
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | nikolsk
# Processing Record 23 of Set 2 | askino
# Processing Record 24 of Set 2 | boralday
# Processing Record 25 of Set 2 | ahipara
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | kropotkin
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | champagnole
# Processing Record 30 of Set 2 | midland
# Processing Record 31 of Set 2 | polewali
# Processing Record 32 of Set 2 | santa cruz de tenerife
# Processing Record 33 of Set 2 | labrea
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | prince rupert
# Processing Record 37 of Set 2 | boende
# Processing Record 38 of Set 2 | chara
# Processing Record 39 of Set 2 | keti bandar
# Processing Record 40 of Set 2 | ust-omchug
# Processing Record 41 of Set 2 | qaqortoq
# Processing Record 42 of Set 2 | inta
# Processing Record 43 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 2 | ilongero
# Processing Record 45 of Set 2 | george
# Processing Record 46 of Set 2 | naugarzan
# City not found. Skipping...
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | alta
# Processing Record 49 of Set 2 | sorong
# Processing Record 50 of Set 2 | coahuayana
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | kawalu
# Processing Record 3 of Set 3 | san ignacio
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | gat
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | balkanabat
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | bonthe
# Processing Record 11 of Set 3 | poum
# Processing Record 12 of Set 3 | fortuna
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 3 | port hedland
# Processing Record 16 of Set 3 | lazaro cardenas
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 3 | bose
# Processing Record 23 of Set 3 | faanui
# Processing Record 24 of Set 3 | hovd
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | blythe
# Processing Record 27 of Set 3 | wagar
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | nemuro
# Processing Record 30 of Set 3 | mabaruma
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | victor harbor
# Processing Record 33 of Set 3 | simpang
# Processing Record 34 of Set 3 | sao jose da coroa grande
# Processing Record 35 of Set 3 | sahuaripa
# Processing Record 36 of Set 3 | muthill
# Processing Record 37 of Set 3 | malacacheta
# Processing Record 38 of Set 3 | teya
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | pasighat
# Processing Record 42 of Set 3 | samarai
# Processing Record 43 of Set 3 | nalus
# Processing Record 44 of Set 3 | lavrentiya
# Processing Record 45 of Set 3 | salinopolis
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | shizunai
# Processing Record 48 of Set 3 | lompoc
# Processing Record 49 of Set 3 | sumbe
# Processing Record 50 of Set 3 | preobrazheniye
# Processing Record 1 of Set 4 | omboue
# Processing Record 2 of Set 4 | sioux lookout
# Processing Record 3 of Set 4 | teluknaga
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | yining
# Processing Record 6 of Set 4 | carupano
# Processing Record 7 of Set 4 | cabinda
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | wanning
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | norrtalje
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | vrontados
# Processing Record 15 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 4 | dikson
# Processing Record 17 of Set 4 | mount gambier
# Processing Record 18 of Set 4 | poya
# Processing Record 19 of Set 4 | hithadhoo
# Processing Record 20 of Set 4 | hauterive
# Processing Record 21 of Set 4 | koscierzyna
# Processing Record 22 of Set 4 | akdepe
# Processing Record 23 of Set 4 | tricase
# Processing Record 24 of Set 4 | ingham
# Processing Record 25 of Set 4 | saint-gilles
# Processing Record 26 of Set 4 | grindavik
# Processing Record 27 of Set 4 | liwale
# Processing Record 28 of Set 4 | tongzi
# Processing Record 29 of Set 4 | nome
# Processing Record 30 of Set 4 | shimoda
# Processing Record 31 of Set 4 | korla
# Processing Record 32 of Set 4 | mahdasht
# Processing Record 33 of Set 4 | hammerfest
# Processing Record 34 of Set 4 | karratha
# Processing Record 35 of Set 4 | saskylakh
# Processing Record 36 of Set 4 | avarua
# Processing Record 37 of Set 4 | melfi
# Processing Record 38 of Set 4 | nuristan
# Processing Record 39 of Set 4 | gorontalo
# Processing Record 40 of Set 4 | inzai
# Processing Record 41 of Set 4 | morgan city
# Processing Record 42 of Set 4 | rosetta
# Processing Record 43 of Set 4 | illapel
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | yar-sale
# Processing Record 46 of Set 4 | surt
# Processing Record 47 of Set 4 | kulu
# Processing Record 48 of Set 4 | chancay
# Processing Record 49 of Set 4 | sawtell
# Processing Record 50 of Set 4 | saint george
# Processing Record 1 of Set 5 | sovetskiy
# Processing Record 2 of Set 5 | calama
# Processing Record 3 of Set 5 | mahajanga
# Processing Record 4 of Set 5 | sistranda
# Processing Record 5 of Set 5 | vao
# Processing Record 6 of Set 5 | hamilton
# Processing Record 7 of Set 5 | talnakh
# Processing Record 8 of Set 5 | oranjemund
# Processing Record 9 of Set 5 | pisco
# Processing Record 10 of Set 5 | tilichiki
# Processing Record 11 of Set 5 | russell
# Processing Record 12 of Set 5 | arlit
# Processing Record 13 of Set 5 | la ronge
# Processing Record 14 of Set 5 | araouane
# Processing Record 15 of Set 5 | cherskiy
# Processing Record 16 of Set 5 | yerbogachen
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | chisindia
# Processing Record 19 of Set 5 | puerto ayora
# Processing Record 20 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 5 | huayang
# Processing Record 22 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 23 of Set 5 | dhidhdhoo
# Processing Record 24 of Set 5 | mahanoro
# Processing Record 25 of Set 5 | bangkal
# Processing Record 26 of Set 5 | alice springs
# Processing Record 27 of Set 5 | taua
# Processing Record 28 of Set 5 | ho
# City not found. Skipping...
# Processing Record 29 of Set 5 | parichhatgarh
# Processing Record 30 of Set 5 | ibra
# Processing Record 31 of Set 5 | hilo
# Processing Record 32 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 5 | georgetown
# Processing Record 34 of Set 5 | wonthaggi
# Processing Record 35 of Set 5 | mae hong son
# Processing Record 36 of Set 5 | boyuibe
# Processing Record 37 of Set 5 | san cristobal
# Processing Record 38 of Set 5 | birjand
# Processing Record 39 of Set 5 | yajalon
# Processing Record 40 of Set 5 | pandan
# Processing Record 41 of Set 5 | kloulklubed
# Processing Record 42 of Set 5 | conde
# Processing Record 43 of Set 5 | padang
# Processing Record 44 of Set 5 | kingaroy
# Processing Record 45 of Set 5 | manzanillo
# Processing Record 46 of Set 5 | maple creek
# Processing Record 47 of Set 5 | norman wells
# Processing Record 48 of Set 5 | bajo baudo
# City not found. Skipping...
# Processing Record 49 of Set 5 | puerto escondido
# Processing Record 50 of Set 5 | eyl
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | puerto maldonado
# Processing Record 3 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | jalu
# Processing Record 6 of Set 6 | hasaki
# Processing Record 7 of Set 6 | lipno
# Processing Record 8 of Set 6 | roma
# Processing Record 9 of Set 6 | severo-kurilsk
# Processing Record 10 of Set 6 | shirokiy
# Processing Record 11 of Set 6 | kavieng
# Processing Record 12 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 6 | lushunkou
# City not found. Skipping...
# Processing Record 14 of Set 6 | menongue
# Processing Record 15 of Set 6 | palembang
# Processing Record 16 of Set 6 | chicama
# Processing Record 17 of Set 6 | port macquarie
# Processing Record 18 of Set 6 | sao gabriel da cachoeira
# Processing Record 19 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 6 | zhigansk
# Processing Record 21 of Set 6 | touros
# Processing Record 22 of Set 6 | jibuti
# Processing Record 23 of Set 6 | mnogovershinnyy
# Processing Record 24 of Set 6 | leningradskiy
# Processing Record 25 of Set 6 | lemesos
# City not found. Skipping...
# Processing Record 26 of Set 6 | shelburne
# Processing Record 27 of Set 6 | kruisfontein
# Processing Record 28 of Set 6 | bathsheba
# Processing Record 29 of Set 6 | vostok
# Processing Record 30 of Set 6 | whitehaven
# Processing Record 31 of Set 6 | saint-louis
# Processing Record 32 of Set 6 | beringovskiy
# Processing Record 33 of Set 6 | port-cartier
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | baruun-urt
# Processing Record 36 of Set 6 | panino
# Processing Record 37 of Set 6 | saint-pierre
# Processing Record 38 of Set 6 | berlevag
# Processing Record 39 of Set 6 | cabedelo
# Processing Record 40 of Set 6 | slave lake
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 6 | hov
# Processing Record 44 of Set 6 | asfi
# Processing Record 45 of Set 6 | matadi
# Processing Record 46 of Set 6 | jacareacanga
# Processing Record 47 of Set 6 | bubaque
# Processing Record 48 of Set 6 | kushiro
# Processing Record 49 of Set 6 | auki
# Processing Record 50 of Set 6 | progreso
# Processing Record 1 of Set 7 | maragogi
# Processing Record 2 of Set 7 | oreanda
# City not found. Skipping...
# Processing Record 3 of Set 7 | kodinsk
# Processing Record 4 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 7 | roches noires
# City not found. Skipping...
# Processing Record 6 of Set 7 | riyadh
# Processing Record 7 of Set 7 | mirnyy
# Processing Record 8 of Set 7 | richards bay
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | marsa matruh
# Processing Record 11 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 7 | ketchikan
# Processing Record 14 of Set 7 | ancud
# Processing Record 15 of Set 7 | hellin
# Processing Record 16 of Set 7 | los llanos de aridane
# Processing Record 17 of Set 7 | alta floresta
# Processing Record 18 of Set 7 | praxedis guerrero
# Processing Record 19 of Set 7 | verkhnyaya maksakovka
# Processing Record 20 of Set 7 | saint-francois
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | eureka
# Processing Record 23 of Set 7 | dingle
# Processing Record 24 of Set 7 | acapulco
# Processing Record 25 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 7 | bad sooden-allendorf
# Processing Record 27 of Set 7 | general roca
# Processing Record 28 of Set 7 | vardo
# Processing Record 29 of Set 7 | hastings
# Processing Record 30 of Set 7 | shizuishan
# Processing Record 31 of Set 7 | uribia
# Processing Record 32 of Set 7 | half moon bay
# Processing Record 33 of Set 7 | ploemeur
# Processing Record 34 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 7 | ekhabi
# Processing Record 36 of Set 7 | hambantota
# Processing Record 37 of Set 7 | buala
# Processing Record 38 of Set 7 | malkapur
# Processing Record 39 of Set 7 | necochea
# Processing Record 40 of Set 7 | asau
# Processing Record 41 of Set 7 | boa vista
# Processing Record 42 of Set 7 | bandarbeyla
# Processing Record 43 of Set 7 | henties bay
# Processing Record 44 of Set 7 | raghunathpur
# Processing Record 45 of Set 7 | sicamous
# Processing Record 46 of Set 7 | hadsten
# Processing Record 47 of Set 7 | lechinta
# Processing Record 48 of Set 7 | muros
# Processing Record 49 of Set 7 | goderich
# Processing Record 50 of Set 7 | te anau
# Processing Record 1 of Set 8 | luba
# Processing Record 2 of Set 8 | shaoyang
# Processing Record 3 of Set 8 | rio grande
# Processing Record 4 of Set 8 | marsh harbour
# Processing Record 5 of Set 8 | vieques
# Processing Record 6 of Set 8 | maniitsoq
# Processing Record 7 of Set 8 | telenesti
# Processing Record 8 of Set 8 | kangshan
# Processing Record 9 of Set 8 | jinan
# Processing Record 10 of Set 8 | celestun
# Processing Record 11 of Set 8 | qitaihe
# Processing Record 12 of Set 8 | jurado
# Processing Record 13 of Set 8 | parnamirim
# Processing Record 14 of Set 8 | dvorichna
# Processing Record 15 of Set 8 | manavgat
# Processing Record 16 of Set 8 | hay river
# Processing Record 17 of Set 8 | aswan
# Processing Record 18 of Set 8 | toktogul
# Processing Record 19 of Set 8 | kamenka
# Processing Record 20 of Set 8 | vila
# Processing Record 21 of Set 8 | burica
# City not found. Skipping...
# Processing Record 22 of Set 8 | flinders
# Processing Record 23 of Set 8 | buenos aires
# Processing Record 24 of Set 8 | catuday
# Processing Record 25 of Set 8 | amapa
# Processing Record 26 of Set 8 | borovoy
# Processing Record 27 of Set 8 | luderitz
# Processing Record 28 of Set 8 | simao
# Processing Record 29 of Set 8 | hofn
# Processing Record 30 of Set 8 | westport
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | la romana
# Processing Record 33 of Set 8 | camacha
# Processing Record 34 of Set 8 | derzhavinsk
# Processing Record 35 of Set 8 | nuevo mexico
# Processing Record 36 of Set 8 | grants
# Processing Record 37 of Set 8 | weihai
# Processing Record 38 of Set 8 | praia da vitoria
# Processing Record 39 of Set 8 | xai-xai
# Processing Record 40 of Set 8 | kahului
# Processing Record 41 of Set 8 | luanda
# Processing Record 42 of Set 8 | mayo
# Processing Record 43 of Set 8 | vengerovo
# Processing Record 44 of Set 8 | bacungan
# Processing Record 45 of Set 8 | mattru
# Processing Record 46 of Set 8 | caravelas
# Processing Record 47 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 8 | mazagao
# Processing Record 49 of Set 8 | carnarvon
# Processing Record 50 of Set 8 | fort nelson
# Processing Record 1 of Set 9 | antalaha
# Processing Record 2 of Set 9 | tsumeb
# Processing Record 3 of Set 9 | paamiut
# Processing Record 4 of Set 9 | quatre cocos
# Processing Record 5 of Set 9 | alenquer
# Processing Record 6 of Set 9 | krasnoselkup
# Processing Record 7 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 9 | birao
# Processing Record 9 of Set 9 | waipawa
# Processing Record 10 of Set 9 | clyde river
# Processing Record 11 of Set 9 | olafsvik
# Processing Record 12 of Set 9 | nogliki
# Processing Record 13 of Set 9 | saint anthony
# Processing Record 14 of Set 9 | camocim
# Processing Record 15 of Set 9 | kanke
# Processing Record 16 of Set 9 | pundaguitan
# Processing Record 17 of Set 9 | waingapu
# Processing Record 18 of Set 9 | bengkulu
# Processing Record 19 of Set 9 | ampanihy
# Processing Record 20 of Set 9 | banjarmasin
# Processing Record 21 of Set 9 | comodoro rivadavia
# Processing Record 22 of Set 9 | san patricio
# Processing Record 23 of Set 9 | talaya
# Processing Record 24 of Set 9 | takoradi
# Processing Record 25 of Set 9 | komsomolskiy
# Processing Record 26 of Set 9 | balabac
# Processing Record 27 of Set 9 | manta
# Processing Record 28 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 29 of Set 9 | bardiyah
# Processing Record 30 of Set 9 | khandyga
# Processing Record 31 of Set 9 | namatanai
# Processing Record 32 of Set 9 | flin flon
# Processing Record 33 of Set 9 | monroe
# Processing Record 34 of Set 9 | miramar
# Processing Record 35 of Set 9 | huarmey
# Processing Record 36 of Set 9 | harper
# Processing Record 37 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 38 of Set 9 | valenza
# Processing Record 39 of Set 9 | lugovoy
# Processing Record 40 of Set 9 | alibag
# Processing Record 41 of Set 9 | haines junction
# Processing Record 42 of Set 9 | liaoyang
# Processing Record 43 of Set 9 | malmyzh
# Processing Record 44 of Set 9 | uch
# Processing Record 45 of Set 9 | ucluelet
# Processing Record 46 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 9 | nishihara
# Processing Record 48 of Set 9 | tendukheda
# Processing Record 49 of Set 9 | port angeles
# Processing Record 50 of Set 9 | lasa
# Processing Record 1 of Set 10 | lagunas
# Processing Record 2 of Set 10 | imperia
# Processing Record 3 of Set 10 | taksimo
# Processing Record 4 of Set 10 | sitka
# Processing Record 5 of Set 10 | aracati
# Processing Record 6 of Set 10 | urucui
# Processing Record 7 of Set 10 | dzhebariki-khaya
# Processing Record 8 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 10 | ullapool
# Processing Record 10 of Set 10 | atar
# Processing Record 11 of Set 10 | bairiki
# Processing Record 12 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 10 | gueret
# Processing Record 14 of Set 10 | jiuquan
# Processing Record 15 of Set 10 | kiama
# Processing Record 16 of Set 10 | talcahuano
# Processing Record 17 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 18 of Set 10 | margate
# Processing Record 19 of Set 10 | yatou
# Processing Record 20 of Set 10 | port-gentil
# Processing Record 21 of Set 10 | nyagan
# Processing Record 22 of Set 10 | kutum
# Processing Record 23 of Set 10 | vilhena
# Processing Record 24 of Set 10 | adrar
# Processing Record 25 of Set 10 | banda aceh
# Processing Record 26 of Set 10 | domoni
# Processing Record 27 of Set 10 | tessalit
# Processing Record 28 of Set 10 | saint-augustin
# Processing Record 29 of Set 10 | pacific grove
# Processing Record 30 of Set 10 | sidi ali
# Processing Record 31 of Set 10 | lipin bor
# Processing Record 32 of Set 10 | shingu
# Processing Record 33 of Set 10 | galle
# Processing Record 34 of Set 10 | awjilah
# Processing Record 35 of Set 10 | dubuque
# Processing Record 36 of Set 10 | mantua
# Processing Record 37 of Set 10 | wiang sa
# Processing Record 38 of Set 10 | portland
# Processing Record 39 of Set 10 | tukrah
# Processing Record 40 of Set 10 | kieta
# Processing Record 41 of Set 10 | hanting
# Processing Record 42 of Set 10 | hualmay
# Processing Record 43 of Set 10 | batagay-alyta
# Processing Record 44 of Set 10 | sao felix do xingu
# Processing Record 45 of Set 10 | brae
# Processing Record 46 of Set 10 | pombos
# Processing Record 47 of Set 10 | belaya gora
# Processing Record 48 of Set 10 | vestmannaeyjar
# Processing Record 49 of Set 10 | terra santa
# Processing Record 50 of Set 10 | katobu
# Processing Record 1 of Set 11 | muchkapskiy
# Processing Record 2 of Set 11 | bargi
# Processing Record 3 of Set 11 | sinnamary
# Processing Record 4 of Set 11 | lensk
# Processing Record 5 of Set 11 | porto novo
# Processing Record 6 of Set 11 | colac
# Processing Record 7 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 11 | kevsala
# Processing Record 10 of Set 11 | umm lajj
# Processing Record 11 of Set 11 | byron bay
# Processing Record 12 of Set 11 | tecoanapa
# Processing Record 13 of Set 11 | dharapuram
# Processing Record 14 of Set 11 | labuhan
# Processing Record 15 of Set 11 | puerto cabezas
# Processing Record 16 of Set 11 | aksarka
# Processing Record 17 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 11 | aasiaat
# Processing Record 19 of Set 11 | neiafu
# Processing Record 20 of Set 11 | liverpool
# Processing Record 21 of Set 11 | ust-nera
# Processing Record 22 of Set 11 | dutlwe
# Processing Record 23 of Set 11 | waitati
# Processing Record 24 of Set 11 | isangel
# Processing Record 25 of Set 11 | boden
# Processing Record 26 of Set 11 | burgeo
# Processing Record 27 of Set 11 | durban
# Processing Record 28 of Set 11 | fiumicino
# Processing Record 29 of Set 11 | naigarhi
# Processing Record 30 of Set 11 | salym
# Processing Record 31 of Set 11 | nayoro
# Processing Record 32 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 11 | palmer
# Processing Record 34 of Set 11 | sosnovo-ozerskoye
# Processing Record 35 of Set 11 | kandry
# Processing Record 36 of Set 11 | mahon
# Processing Record 37 of Set 11 | faridkot
# Processing Record 38 of Set 11 | tonekabon
# Processing Record 39 of Set 11 | ipora
# Processing Record 40 of Set 11 | merauke
# Processing Record 41 of Set 11 | santa ana
# Processing Record 42 of Set 11 | alofi
# Processing Record 43 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 44 of Set 11 | yangambi
# Processing Record 45 of Set 11 | knysna
# Processing Record 46 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 11 | kingsville
# Processing Record 48 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 49 of Set 11 | kavaratti
# Processing Record 50 of Set 11 | jedburgh
# Processing Record 1 of Set 12 | iringa
# Processing Record 2 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 12 | darlawn
# Processing Record 4 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 12 | ulety
# Processing Record 6 of Set 12 | statesboro
# Processing Record 7 of Set 12 | lac du bonnet
# Processing Record 8 of Set 12 | kerema
# Processing Record 9 of Set 12 | starogard gdanski
# Processing Record 10 of Set 12 | coihaique
# Processing Record 11 of Set 12 | iqaluit
# Processing Record 12 of Set 12 | zielona gora
# Processing Record 13 of Set 12 | atambua
# Processing Record 14 of Set 12 | waterford
# Processing Record 15 of Set 12 | uroteppa
# City not found. Skipping...
# Processing Record 16 of Set 12 | baoqing
# Processing Record 17 of Set 12 | inongo
# Processing Record 18 of Set 12 | waycross
# Processing Record 19 of Set 12 | katangli
# Processing Record 20 of Set 12 | shirvan
# Processing Record 21 of Set 12 | codrington
# Processing Record 22 of Set 12 | fresno
# Processing Record 23 of Set 12 | ninotsminda
# Processing Record 24 of Set 12 | novobirilyussy
# Processing Record 25 of Set 12 | neuquen
# Processing Record 26 of Set 12 | mount isa
# Processing Record 27 of Set 12 | qui nhon
# Processing Record 28 of Set 12 | greiz
# Processing Record 29 of Set 12 | emba
# Processing Record 30 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 31 of Set 12 | itacoatiara
# Processing Record 32 of Set 12 | rocha
# Processing Record 33 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 12 | magdalena
# Processing Record 35 of Set 12 | nantucket
# Processing Record 36 of Set 12 | salalah
# Processing Record 37 of Set 12 | mango
# Processing Record 38 of Set 12 | alcaudete
# Processing Record 39 of Set 12 | nizhnyaya omka
# Processing Record 40 of Set 12 | rafraf
# Processing Record 41 of Set 12 | chimbote
# Processing Record 42 of Set 12 | zyryanka
# Processing Record 43 of Set 12 | bilibino
# Processing Record 44 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 12 | capitan bado
# Processing Record 46 of Set 12 | porbandar
# Processing Record 47 of Set 12 | otane
# Processing Record 48 of Set 12 | college
# Processing Record 49 of Set 12 | urusha
# Processing Record 50 of Set 12 | bashmakovo
# Processing Record 1 of Set 13 | wetaskiwin
# Processing Record 2 of Set 13 | tadine
# Processing Record 3 of Set 13 | malpe
# Processing Record 4 of Set 13 | frontera
# Processing Record 5 of Set 13 | samarkand
# Processing Record 6 of Set 13 | avera
# Processing Record 7 of Set 13 | ayorou
# Processing Record 8 of Set 13 | chumikan
# Processing Record 9 of Set 13 | getulio vargas
# Processing Record 10 of Set 13 | falmouth
# Processing Record 11 of Set 13 | satun
# Processing Record 12 of Set 13 | dicabisagan
# Processing Record 13 of Set 13 | winslow
# Processing Record 14 of Set 13 | mogadishu
# Processing Record 15 of Set 13 | simbahan
# Processing Record 16 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 13 | kaman
# Processing Record 18 of Set 13 | novoagansk
# Processing Record 19 of Set 13 | kirakira
# Processing Record 20 of Set 13 | svetlyy yar
# Processing Record 21 of Set 13 | mwense
# Processing Record 22 of Set 13 | kielce
# Processing Record 23 of Set 13 | beruwala
# Processing Record 24 of Set 13 | pyapon
# Processing Record 25 of Set 13 | tahe
# Processing Record 26 of Set 13 | muravlenko
# Processing Record 27 of Set 13 | pervomayskiy
# Processing Record 28 of Set 13 | vila franca do campo
# Processing Record 29 of Set 13 | kupang
# Processing Record 30 of Set 13 | egvekinot
# Processing Record 31 of Set 13 | borba
# Processing Record 32 of Set 13 | laguna
# Processing Record 33 of Set 13 | dwarka
# Processing Record 34 of Set 13 | ixtapa
# Processing Record 35 of Set 13 | tiarei
# Processing Record 36 of Set 13 | baraboo
# Processing Record 37 of Set 13 | ostersund
# Processing Record 38 of Set 13 | clarence town
# Processing Record 39 of Set 13 | luau
# Processing Record 40 of Set 13 | praya
# Processing Record 41 of Set 13 | tartagal
# Processing Record 42 of Set 13 | oistins
# Processing Record 43 of Set 13 | warrington
# Processing Record 44 of Set 13 | kidal
# Processing Record 45 of Set 13 | pontianak
# Processing Record 46 of Set 13 | bitung
# Processing Record 47 of Set 13 | gravelbourg
# Processing Record 48 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 13 | ialibu
# Processing Record 50 of Set 13 | vieste
# Processing Record 1 of Set 14 | mbacke
# City not found. Skipping...
# Processing Record 2 of Set 14 | kihei
# Processing Record 3 of Set 14 | san juan
# Processing Record 4 of Set 14 | evensk
# Processing Record 5 of Set 14 | okhotsk
# Processing Record 6 of Set 14 | husavik
# Processing Record 7 of Set 14 | marabba
# Processing Record 8 of Set 14 | bilma
# Processing Record 9 of Set 14 | balakhninskiy
# Processing Record 10 of Set 14 | belyy yar
# Processing Record 11 of Set 14 | yulara
# Processing Record 12 of Set 14 | kapuskasing
# Processing Record 13 of Set 14 | pangnirtung
# Processing Record 14 of Set 14 | saryozek
# Processing Record 15 of Set 14 | palauig
# Processing Record 16 of Set 14 | beloha
# Processing Record 17 of Set 14 | vagur
# Processing Record 18 of Set 14 | san pedro de macoris
# Processing Record 19 of Set 14 | paragominas
# Processing Record 20 of Set 14 | mutoko
# Processing Record 21 of Set 14 | solwezi
# Processing Record 22 of Set 14 | lima
# Processing Record 23 of Set 14 | olhao
# Processing Record 24 of Set 14 | nuuk
# Processing Record 25 of Set 14 | chiknayakanhalli
# Processing Record 26 of Set 14 | dunedin
# Processing Record 27 of Set 14 | pak phanang
# Processing Record 28 of Set 14 | lokachi
# Processing Record 29 of Set 14 | bento goncalves
# Processing Record 30 of Set 14 | alamosa
# Processing Record 31 of Set 14 | batouri
# Processing Record 32 of Set 14 | yeppoon
# Processing Record 33 of Set 14 | moerai
# Processing Record 34 of Set 14 | mehamn
# Processing Record 35 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 14 | shunyi
# Processing Record 37 of Set 14 | ozinki
# Processing Record 38 of Set 14 | bad kreuznach
# Processing Record 39 of Set 14 | marsabit
# Processing Record 40 of Set 14 | killybegs
# Processing Record 41 of Set 14 | moindou
# Processing Record 42 of Set 14 | akyab
# Processing Record 43 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 14 | cabanas
# Processing Record 45 of Set 14 | alyangula
# Processing Record 46 of Set 14 | sirjan
# Processing Record 47 of Set 14 | ransang
# Processing Record 48 of Set 14 | luganville
# Processing Record 49 of Set 14 | verkhnyaya inta
# Processing Record 50 of Set 14 | razdolinsk
# Processing Record 1 of Set 15 | forbes
# Processing Record 2 of Set 15 | sembe
# Processing Record 3 of Set 15 | sitangkai
# Processing Record 4 of Set 15 | ashtabula
# Processing Record 5 of Set 15 | cap malheureux
# Processing Record 6 of Set 15 | kizilskoye
# Processing Record 7 of Set 15 | kampong thum
# Processing Record 8 of Set 15 | ostrovnoy
# Processing Record 9 of Set 15 | lata
# Processing Record 10 of Set 15 | garowe
# Processing Record 11 of Set 15 | chapais
# Processing Record 12 of Set 15 | cochrane
# Processing Record 13 of Set 15 | ballina
# Processing Record 14 of Set 15 | miraflores
# Processing Record 15 of Set 15 | codogno
# Processing Record 16 of Set 15 | marawi
# Processing Record 17 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 18 of Set 15 | moron
# Processing Record 19 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 15 | presidencia roque saenz pena
# Processing Record 21 of Set 15 | rosa zarate
# Processing Record 22 of Set 15 | kiunga
# Processing Record 23 of Set 15 | oxapampa
# Processing Record 24 of Set 15 | saldanha
# Processing Record 25 of Set 15 | wattegama
# Processing Record 26 of Set 15 | basoko
# Processing Record 27 of Set 15 | erenhot
# Processing Record 28 of Set 15 | brownsburg
# Processing Record 29 of Set 15 | tokur
# Processing Record 30 of Set 15 | kudahuvadhoo
# Processing Record 31 of Set 15 | mbalmayo
# Processing Record 32 of Set 15 | nouadhibou
# Processing Record 33 of Set 15 | sinnar
# Processing Record 34 of Set 15 | ihosy
# Processing Record 35 of Set 15 | aykhal
# Processing Record 36 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 15 | leh
# Processing Record 38 of Set 15 | karpathos
# Processing Record 39 of Set 15 | ratanpur
# Processing Record 40 of Set 15 | mormugao
# Processing Record 41 of Set 15 | igboho
# Processing Record 42 of Set 15 | nyurba
# Processing Record 43 of Set 15 | koslan
# Processing Record 44 of Set 15 | kostino
# Processing Record 45 of Set 15 | phek
# Processing Record 46 of Set 15 | jawhar
# Processing Record 47 of Set 15 | chalus
# Processing Record 48 of Set 15 | marzuq
# Processing Record 49 of Set 15 | malumfashi
# Processing Record 50 of Set 15 | lovozero
# Processing Record 1 of Set 16 | dalvik
# Processing Record 2 of Set 16 | khorinsk
# Processing Record 3 of Set 16 | krasnogorsk
# Processing Record 4 of Set 16 | oksfjord
# Processing Record 5 of Set 16 | ahumada
# City not found. Skipping...
# Processing Record 6 of Set 16 | ambilobe
# Processing Record 7 of Set 16 | iquitos
# Processing Record 8 of Set 16 | tenenkou
# Processing Record 9 of Set 16 | farmington
# Processing Record 10 of Set 16 | kibala
# Processing Record 11 of Set 16 | jega
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tuatapere      NZ -46.13  167.68     72.00        49         100
# 1  Arraial Do Cabo      BR -22.97  -42.03     73.40        78          40
# 2           Matane      CA  48.83  -67.52     43.00         1         100
# 3            Kapaa      US  22.08 -159.32     81.00        78          90
# 4           Broome      US  42.25  -75.83     64.99        77           1
# 5       Batticaloa      LK   7.71   81.69     77.63        74           0
# 6          Ushuaia      AR -54.80  -68.30     42.80        70          75
# 7   Guerrero Negro      MX  27.98 -114.06     68.20        76           0
# 8            Kuryk      KZ  43.20   51.65     53.47        59          11
# 9             Bend      US  44.06 -121.32     60.80        44          40
#
#    Wind Speed Current Description
# 0       14.00     overcast clouds
# 1       13.87    scattered clouds
# 2        9.13     overcast clouds
# 3       12.75     overcast clouds
# 4       10.29           clear sky
# 5        6.67           clear sky
# 6        9.17       broken clouds
# 7       13.73           clear sky
# 8        8.55          few clouds
# 9       12.75    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp",'Humidity',"Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tuatapere      NZ -46.13  167.68     72.00        49         100
# 1  Arraial Do Cabo      BR -22.97  -42.03     73.40        78          40
# 2           Matane      CA  48.83  -67.52     43.00         1         100
# 3            Kapaa      US  22.08 -159.32     81.00        78          90
# 4           Broome      US  42.25  -75.83     64.99        77           1
# 5       Batticaloa      LK   7.71   81.69     77.63        74           0
# 6          Ushuaia      AR -54.80  -68.30     42.80        70          75
# 7   Guerrero Negro      MX  27.98 -114.06     68.20        76           0
# 8            Kuryk      KZ  43.20   51.65     53.47        59          11
# 9             Bend      US  44.06 -121.32     60.80        44          40
#
#    Wind Speed Current Description
# 0       14.00     overcast clouds
# 1       13.87    scattered clouds
# 2        9.13     overcast clouds
# 3       12.75     overcast clouds
# 4       10.29           clear sky
# 5        6.67           clear sky
# 6        9.17       broken clouds
# 7       13.73           clear sky
# 8        8.55          few clouds
# 9       12.75    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
